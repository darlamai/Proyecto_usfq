# %%
import pandas as pd
from pathlib import Path

# %%
ruta = Path(__file__).parent
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 ruta = Path(__file__).parent
#
# NameError: name '__file__' is not defined

# %%
ruta = Path.cwd()
print("Directorio actual:", ruta)
# Out:
# Directorio actual: d:\OneDrive - SUPERINTENDENCIA DE BANCOS\Escritorio\Proyecto_usfq\src

# %%
ruta=Path(".../data")

# %%
archivos=list(ruta.glob("*.xlsx"))

# %%
ruta=Path(".../data")

# %%
ruta
# Out:
# WindowsPath('.../data')
