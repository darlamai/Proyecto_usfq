# %% [markdown]
# ## Preprocesamiento de la data

# %% [markdown]
# ### Carga de las librerías y de los módulos

# %% [markdown]
# Se cargan las librerías para el manejo de rutas, variables numéricas y configuración del entorno de ejecución.
#
# Por lo que se agrega el directorio padre al path para poder importar los módulos desarrollados dentro de la carpeta `src`.
# Se importan los módulos del proyecto que contienen las funciones de carga, transformación y feature engineering, empleando la función `reload` de `importlib`, con el fin de ir actualizando las dunciones dentro del notebook sin reiniciar todo el entorno.

# %%
from pathlib import Path

RAIZ_PROYECTO = "."

# %%
# Parameters
RAIZ_PROYECTO = "C:\\Users\\ASUS\\Desktop\\proyecto_usfq\\Proyecto_usfq"

# %%
RAIZ_PROYECTO = Path(RAIZ_PROYECTO)

print(f"Raíz del proyecto: {RAIZ_PROYECTO}")
# Out:
# Raíz del proyecto: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq

# %%
import sys
from pathlib import Path
import numpy as np

# Se agrega la raíz del proyecto al path de Python para permitir
# la importación de los módulos almacenados en la carpeta src.
sys.path.append(str(Path(RAIZ_PROYECTO)))

# %%
import pandas as pd
import importlib

import json
from datetime import datetime

from src import load
from src import feature_engineering

# %%
importlib.reload(load)
importlib.reload(feature_engineering)
# Out:
# <module 'src.feature_engineering' from 'C:\\Users\\ASUS\\Desktop\\proyecto_usfq\\Proyecto_usfq\\src\\feature_engineering.py'>

# %% [markdown]
# ### Integración de los datos de todos los indicadores

# %% [markdown]
# En esta etapa se integran en un único dataset de análisis los indicadores financieros extraídos de los boletines de la Superintendencia de Bancos, los indicadores construidos y derivados de la cartera y las variaciones construidas de las principales cuentas del balance,por medio de un pipeline elaborado con las funciones de los scripts cargadas de la carpeta `src`.
#
#
# Para este fin, el propio ente de control advierte en su página de boletines financieros mensuales (https://www.superbancos.gob.ec/estadisticas/portalestudios/bancos/) que: "....Los boletines financieros mensuales de Sistema Financiero se prepararon conforme los planes y catálogos de cuentas vigentes a la fecha de corte del boletín. En los datos estadísticos de los boletines y los boletines en Serie se realizó un proceso de homologación de la información financiera para que los datos sean comparables en el tiempo (reexpresar los datos históricos a un plan de cuentas, en este caso se han homologado a la normativa vigente desde 1 mayo 2021)."
#
# Este detalle de fechas es importante puesto que, para evitar problemas de unficación de toda la data es necesario que los excels estén homologados. Para el presente proyecto se consideran los boletines financieros mensuales desde Mayo de 2021. Al incluir las variaciones interanuales de las cuentas principales del balance nuestro análisis se rezaga a un año después, por lo que nuestro dataset comienza desde Mayo 2022 hasta el último boletín publicado por el ente de control de Julio 2026.
#
#
# La integración se realiza utilizando como claves de identificación el año, mes y entidad financiera.

# %%
anios=range(2022,2027)

# %%
# Lista donde se almacenará la información integrada de cada año.
datasets_anuales=[]
# Se recorre para cada año el pipeline de preprocessing y feature engineering para los indicadores generales financieros y los indicadores de cartera
#  y se almacena los resultados por año para posteriormente
# integrar todos los años en una sola base
for i in anios:
    indicadores=load.procesar_indicadores(i, load.archivos,load.meses, load.columnas_indicadores)
    lista_cartera=load.procesar_cartera(i, load.archivos,load.meses)
    indicadores_cartera=feature_engineering.feature_engineering_cartera(lista_cartera)
    lista_indicadores_y_cartera=feature_engineering.unir_todos_indicadores(indicadores, indicadores_cartera)
    indicadores_y_cartera=pd.concat(lista_indicadores_y_cartera,
        ignore_index=True)
    datasets_anuales.append(indicadores_y_cartera)
# Out:
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2022\FINANCIERO MENSUAL BANCA PRIVADA 2022_01.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2022\FINANCIERO MENSUAL BANCA PRIVADA 2022_02.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2022\FINANCIERO MENSUAL BANCA PRIVADA 2022_03.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2022\FINANCIERO MENSUAL BANCA PRIVADA 2022_04.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2022\FINANCIERO MENSUAL BANCA PRIVADA 2022_05_rev.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2022\FINANCIERO MENSUAL BANCA PRIVADA 2022_06.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2022\FINANCIERO MENSUAL BANCA PRIVADA 2022_07.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2022\FINANCIERO MENSUAL BANCA PRIVADA 2022_08.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2022\FINANCIERO MENSUAL BANCA PRIVADA 2022_09.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2022\FINANCIERO MENSUAL BANCA PRIVADA 2022_10.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2022\FINANCIERO MENSUAL BANCA PRIVADA 2022_11.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2022\FINANCIERO MENSUAL BANCA PRIVADA 2022_12.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2023\FINANCIERO MENSUAL BANCA PRIVADA 2023_01.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2023\FINANCIERO MENSUAL BANCA PRIVADA 2023_02.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2023\FINANCIERO MENSUAL BANCA PRIVADA 2023_03.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2023\FINANCIERO MENSUAL BANCA PRIVADA 2023_04.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2023\FINANCIERO MENSUAL BANCA PRIVADA 2023_05.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2023\FINANCIERO MENSUAL BANCA PRIVADA 2023_06.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2023\FINANCIERO MENSUAL BANCA PRIVADA 2023_07.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2023\FINANCIERO MENSUAL BANCA PRIVADA 2023_08.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2023\FINANCIERO MENSUAL BANCA PRIVADA 2023_09.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2023\FINANCIERO MENSUAL BANCA PRIVADA 2023_10.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2023\FINANCIERO MENSUAL BANCA PRIVADA 2023_11.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2023\FINANCIERO MENSUAL BANCA PRIVADA 2023_12.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2024\FINANCIERO MENSUAL BANCA PRIVADA 2024_01.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2024\FINANCIERO MENSUAL BANCA PRIVADA 2024_02.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2024\FINANCIERO MENSUAL BANCA PRIVADA 2024_03.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2024\FINANCIERO MENSUAL BANCA PRIVADA 2024_04.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2024\FINANCIERO MENSUAL BANCA PRIVADA 2024_05.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2024\FINANCIERO MENSUAL BANCA PRIVADA 2024_06.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2024\FINANCIERO MENSUAL BANCA PRIVADA 2024_07.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2024\FINANCIERO MENSUAL BANCA PRIVADA 2024_08.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2024\FINANCIERO MENSUAL BANCA PRIVADA 2024_09.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2024\FINANCIERO MENSUAL BANCA PRIVADA 2024_10.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2024\FINANCIERO MENSUAL BANCA PRIVADA 2024_11.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2024\FINANCIERO MENSUAL BANCA PRIVADA 2024_12.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2025\FINANCIERO MENSUAL BANCA PRIVADA 2025_01.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2025\FINANCIERO MENSUAL BANCA PRIVADA 2025_02.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2025\FINANCIERO MENSUAL BANCA PRIVADA 2025_03.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2025\FINANCIERO MENSUAL BANCA PRIVADA 2025_04.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2025\FINANCIERO MENSUAL BANCA PRIVADA 2025_05.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2025\FINANCIERO MENSUAL BANCA PRIVADA 2025_06.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2025\FINANCIERO MENSUAL BANCA PRIVADA 2025_07.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2025\FINANCIERO MENSUAL BANCA PRIVADA 2025_08.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2025\FINANCIERO MENSUAL BANCA PRIVADA 2025_09.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2025\FINANCIERO MENSUAL BANCA PRIVADA 2025_10.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2025\FINANCIERO MENSUAL BANCA PRIVADA 2025_11.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2025\FINANCIERO MENSUAL BANCA PRIVADA 2025_12.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2026\FINANCIERO MENSUAL BANCA PRIVADA 2026_01.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2026\FINANCIERO MENSUAL BANCA PRIVADA 2026_02.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2026\FINANCIERO MENSUAL BANCA PRIVADA 2026_03.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2026\FINANCIERO MENSUAL BANCA PRIVADA 2026_04.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2026\FINANCIERO MENSUAL BANCA PRIVADA 2026_05.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2026\FINANCIERO MENSUAL BANCA PRIVADA 2026_06.xlsx
# Leyendo archivo: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data\2026\FINANCIERO MENSUAL BANCA PRIVADA 2026_07.xlsx

# %%
# Se concatenan verticalmente los datasets correspondientes
# a cada año para obtener una única base histórica.
#
# ignore_index=True permite generar un nuevo índice consecutivo
# para el DataFrame resultante.

dataset_indicadores_cartera = pd.concat(
    datasets_anuales,
    ignore_index=True
)

# %%
dataset_indicadores_cartera
# Out:
#         MES   AÑO                                            ENTIDAD  \
# 0     Enero  2022                                       BP GUAYAQUIL
# 1     Enero  2022                                        BP PACIFICO
# 2     Enero  2022                                       BP PICHINCHA
# 3     Enero  2022                                      BP PRODUBANCO
# 4     Enero  2022                                          BP AUSTRO
# ...     ...   ...                                                ...
# 1299  Julio  2026                                         BP CAPITAL
# 1300  Julio  2026                                         BP DELBANK
# 1301  Julio  2026                BP D-MIRO S.A./BANCO ATLÁNTIDA S.A.
# 1302  Julio  2026  BP BANCO  DESARROLLO DE LOS PUEBLOS  S.A., COD...
# 1303  Julio  2026                         BP VISIONFUND ECUADOR S.A.
#
#      ( PATRIMONIO + RESULTADOS ) / ACTIVOS INMOVILIZADOS NETOS (3) (6)  \
# 0                                              4.141498
# 1                                                2.6451
# 2                                            -23.726736
# 3                                               3.21609
# 4                                              1.391251
# ...                                                 ...
# 1299                                           0.743608
# 1300                                           7.435204
# 1301                                           0.788369
# 1302                                           2.990621
# 1303                                           21.25641
#
#      INDICE DE CAPITALIZACION NETO: FK / FI  \
# 0                                  0.084334
# 1                                  0.097085
# 2                                  0.092786
# 3                                    0.0715
# 4                                  0.078349
# ...                                     ...
# 1299                               0.088779
# 1300                               0.288765
# 1301                               0.055191
# 1302                               0.103658
# 1303                               0.128662
#
#      ACTIVOS IMPRODUCTIVOS NETOS / TOTAL ACTIVOS  \
# 0                                        0.14544
# 1                                       0.223376
# 2                                       0.093155
# 3                                       0.144305
# 4                                       0.167015
# ...                                          ...
# 1299                                    0.203118
# 1300                                    0.157979
# 1301                                    0.128191
# 1302                                    0.105249
# 1303                                    0.037131
#
#      ACTIVOS PRODUCTIVOS / TOTAL ACTIVOS  \
# 0                                0.85456
# 1                                0.77662
# 2                                0.90684
# 3                                0.85569
# 4                                0.83298
# ...                                  ...
# 1299                            0.796882
# 1300                            0.842021
# 1301                            0.871809
# 1302                            0.894751
# 1303                            0.962869
#
#      ACTIVOS PRODUCTIVOS / PASIVOS CON COSTO  \
# 0                                    1.20628
# 1                                    1.10437
# 2                                    1.43429
# 3                                    1.43589
# 4                                    1.05067
# ...                                      ...
# 1299                                0.974991
# 1300                                1.769811
# 1301                                 0.96599
# 1302                                1.069191
# 1303                                1.177842
#
#      MOROSIDAD DE LA CARTERA DE CREDITOS CONSUMO  \
# 0                                        0.01425
# 1                                       0.032261
# 2                                       0.032347
# 3                                       0.032538
# 4                                       0.073443
# ...                                          ...
# 1299                                    0.035269
# 1300                                    0.105913
# 1301                                    0.000358
# 1302                                    0.079619
# 1303                                    0.008478
#
#      MOROSIDAD DE LA CARTERA DE CRÉDITOS INMOBILIARIO  ...  \
# 0                                            0.022054  ...
# 1                                            0.034234  ...
# 2                                            0.045745  ...
# 3                                            0.032279  ...
# 4                                            0.016077  ...
# ...                                               ...  ...
# 1299                                                0  ...
# 1300                                         0.000002  ...
# 1301                                                0  ...
# 1302                                         0.006083  ...
# 1303                                                0  ...
#
#      GASTOS DE PERSONAL ESTIMADOS / ACTIVO PROMEDIO (3)  \
# 0                                              0.015297
# 1                                              0.009043
# 2                                              0.011048
# 3                                              0.010637
# 4                                              0.010616
# ...                                                 ...
# 1299                                           0.022017
# 1300                                           0.040853
# 1301                                           0.030823
# 1302                                           0.021339
# 1303                                            0.04589
#
#      RESULTADOS DEL EJERCICIO / PATRIMONIO PROMEDIO  \
# 0                                          0.128519
# 1                                          0.102842
# 2                                          0.113642
# 3                                          0.127418
# 4                                          0.035847
# ...                                             ...
# 1299                                       0.000602
# 1300                                      -0.003508
# 1301                                        0.00906
# 1302                                       0.024556
# 1303                                       0.244274
#
#      RESULTADOS DEL EJERCICIO / ACTIVO PROMEDIO  \
# 0                                      0.012238
# 1                                      0.012095
# 2                                      0.011441
# 3                                      0.010326
# 4                                      0.003303
# ...                                         ...
# 1299                                    0.00008
# 1300                                  -0.001117
# 1301                                   0.000702
# 1302                                     0.0029
# 1303                                   0.034437
#
#      CARTERA BRUTA / (DEPOSITOS A LA VISTA + DEPOSITOS A PLAZO)  \
# 0                                              0.880435
# 1                                              0.854694
# 2                                              0.830851
# 3                                               0.86819
# 4                                              0.671742
# ...                                                 ...
# 1299                                           0.762553
# 1300                                           1.275196
# 1301                                           0.535486
# 1302                                           0.954322
# 1303                                           2.064977
#
#      FONDOS DISPONIBLES / TOTAL DEPOSITOS A CORTO PLAZO  \
# 0                                               0.21366
# 1                                              0.341741
# 2                                              0.178394
# 3                                              0.320233
# 4                                              0.250919
# ...                                                 ...
# 1299                                           0.241408
# 1300                                           0.591112
# 1301                                           0.331037
# 1302                                            0.17721
# 1303                                           0.426914
#
#      CARTERA IMPRODUCTIVA / CARTERA BRUTA CARTERA VENCIDA / CARTERA BRUTA  \
# 0                                0.012428                        0.005401
# 1                                0.031243                        0.015333
# 2                                0.028914                        0.007745
# 3                                0.015483                        0.003208
# 4                                0.039514                        0.014388
# ...                                   ...                             ...
# 1299                             0.043296                        0.002111
# 1300                             0.031132                        0.010960
# 1301                             0.021523                        0.009165
# 1302                             0.099170                        0.040266
# 1303                             0.044672                        0.022074
#
#      CARTERA QUE NO DEVENGA INTERESES / CARTERA BRUTA  \
# 0                                            0.007027
# 1                                            0.015910
# 2                                            0.021169
# 3                                            0.012275
# 4                                            0.025126
# ...                                               ...
# 1299                                         0.041185
# 1300                                         0.020171
# 1301                                         0.012358
# 1302                                         0.058904
# 1303                                         0.022598
#
#      CARTERA REFINANCIADA / CARTERA BRUTA  \
# 0                                0.015168
# 1                                0.109175
# 2                                0.029904
# 3                                0.007283
# 4                                0.079909
# ...                                   ...
# 1299                             0.014315
# 1300                             0.068912
# 1301                             0.028839
# 1302                             0.041134
# 1303                             0.007556
#
#      CARTERA REESTRUCTURADA / CARTERA BRUTA
# 0                                  0.004739
# 1                                  0.039099
# 2                                  0.055667
# 3                                  0.026373
# 4                                  0.026752
# ...                                     ...
# 1299                               0.002475
# 1300                               0.003849
# 1301                               0.007510
# 1302                               0.006622
# 1303                               0.000656
#
# [1304 rows x 27 columns]

# %%
# Se realiza una revisión puntual de una entidad específica
# para verificar la consistencia de sus registros a través
# de los diferentes períodos.

dataset_indicadores_cartera["ENTIDAD"].unique()
# Out:
# array(['BP GUAYAQUIL', 'BP PACIFICO', 'BP PICHINCHA', 'BP PRODUBANCO',
#        'BP AUSTRO', 'BP BOLIVARIANO', 'BP CITIBANK', 'BP DINERS',
#        'BP GENERAL RUMIÑAHUI', 'BP INTERNACIONAL', 'BP LOJA',
#        'BP MACHALA', 'BP SOLIDARIO', 'BP PROCREDIT', 'BP AMAZONAS',
#        'BP BANCO COMERCIAL DE MANABI', 'BP LITORAL', 'BP COOPNACIONAL',
#        'BP CAPITAL', 'BP FINCA S.A./BANCO AMIBANK S.A.', 'BP DELBANK',
#        'BP D-MIRO S.A./BANCO ATLÁNTIDA S.A.',
#        'BP BANCO  DESARROLLO DE LOS PUEBLOS  S.A., CODESARROLLO',
#        'BP VISIONFUND ECUADOR S.A.'], dtype=object)

# %%
# Ahora se carga la lista que incluye las principales cuentas de los balances contables financieros
# y con la función de feature_engineering se construyen las nuevas variables con las variaciones interanuales 

lista_balance=load.procesar_balances(load.archivos,load.meses, load.cuentas)
indicadores_balance=feature_engineering.calcular_variaciones_balance(lista_balance)

# %%
lista_balance[25].info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 24 entries, 0 to 25
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   MES                   24 non-null     str
#  1   AÑO                   24 non-null     int64
#  2   ENTIDAD               24 non-null     str
#  3   FONDOS DISPONIBLES    24 non-null     float64
#  4   INVERSIONES           24 non-null     float64
#  5   CARTERA DE CRÉDITOS   24 non-null     float64
#  6   TOTAL ACTIVO          24 non-null     float64
#  7   Depósitos a la vista  24 non-null     float64
#  8   Depósitos a plazo     24 non-null     float64
#  9   TOTAL PATRIMONIO      24 non-null     float64
# dtypes: float64(7), int64(1), str(2)
# memory usage: 2.1 KB

# %%
indicadores_balance.columns.to_list()
# Out:
# ['MES',
#  'AÑO',
#  'ENTIDAD',
#  'VAR_FONDOS DISPONIBLES',
#  'VAR_INVERSIONES',
#  'VAR_CARTERA DE CRÉDITOS',
#  'VAR_TOTAL ACTIVO',
#  'VAR_Depósitos a la vista',
#  'VAR_Depósitos a plazo',
#  'VAR_TOTAL PATRIMONIO']

# %%
indicadores_balance
# Out:
# 0       MES   AÑO                                            ENTIDAD  \
# 0      Mayo  2022                                       BP GUAYAQUIL
# 1      Mayo  2022                                        BP PACIFICO
# 2      Mayo  2022                                       BP PICHINCHA
# 3      Mayo  2022                                      BP PRODUBANCO
# 4      Mayo  2022                                          BP AUSTRO
# ...     ...   ...                                                ...
# 1203  Julio  2026                                         BP CAPITAL
# 1204  Julio  2026                                         BP DELBANK
# 1205  Julio  2026                BP D-MIRO S.A./BANCO ATLÁNTIDA S.A.
# 1206  Julio  2026  BP BANCO  DESARROLLO DE LOS PUEBLOS  S.A., COD...
# 1207  Julio  2026                         BP VISIONFUND ECUADOR S.A.
#
# 0     VAR_FONDOS DISPONIBLES  VAR_INVERSIONES  VAR_CARTERA DE CRÉDITOS  \
# 0                  -0.153575        -0.031059                 0.219636
# 1                  -0.161024         0.152143                -0.006714
# 2                  -0.345962         0.008894                 0.341896
# 3                  -0.045015        -0.035218                 0.241502
# 4                  -0.159378         0.069119                 0.214098
# ...                      ...              ...                      ...
# 1203               -0.017643         0.545330                 0.434054
# 1204                0.096224        -0.379255                -0.118974
# 1205                1.398896         0.509052                 0.781038
# 1206               -0.585971         0.248656                 0.036946
# 1207                0.114965         0.669452                 0.232972
#
# 0     VAR_TOTAL ACTIVO  VAR_Depósitos a la vista  VAR_Depósitos a plazo  \
# 0             0.108500                  0.144194               0.163349
# 1            -0.002157                 -0.037496               0.076166
# 2             0.106841                  0.090957               0.176605
# 3             0.138065                  0.092976               0.119563
# 4             0.114007                  0.078231               0.048206
# ...                ...                       ...                    ...
# 1203          0.322436                  0.046285               0.445646
# 1204         -0.102445                 -0.125425              -0.227068
# 1205          0.712938                  0.275121               1.096880
# 1206         -0.051873                 -0.138384               0.086575
# 1207          0.232023                  0.450468               0.703935
#
# 0     VAR_TOTAL PATRIMONIO
# 0                 0.080876
# 1                 0.020035
# 2                 0.043768
# 3                 0.077973
# 4                 0.128133
# ...                    ...
# 1203              0.040729
# 1204              0.051840
# 1205             -0.056485
# 1206              0.067031
# 1207              0.078424
#
# [1208 rows x 10 columns]

# %%
# Se integran los indicadores generales y de cartera con las  variaciones interanuales del balance.
#
# AÑO, MES y ENTIDAD constituyen la llave lógica que identifica
# cada observación.
#
# Se utiliza un left join para conservar todas las observaciones
# de la base principal y agregar las variaciones del balance
# cuando existe una coincidencia.

dataset_final = dataset_indicadores_cartera.merge(
    indicadores_balance,
    on=["MES", "AÑO", "ENTIDAD"],
    how="left"
)

# %% [markdown]
# ### Validación y preparación del dataset

# %% [markdown]
# En esta etapa se verifica la estructura, dimensionalidad, tipos de datos, valores nulos, duplicados y valores infinitos de la base integrada.
#
# El objetivo es asegurar que la información tenga una estructura consistente antes de utilizarla en las etapas posteriores de análisis exploratorio y modelamiento.

# %%
# Se verifica la cantidad inicial de filas y columnas de la base.
dataset_final.shape
# Out:
# (1304, 34)

# %%
# Se excluyen los registros correspondientes a enero-abril de 2022.
#
# Estos períodos no serán considerados en el análisis debido a que
# no forman parte del período comparable definido para el estudio y especificado por el ente de control

dataset_final = dataset_final[
    ~(
        (dataset_final["AÑO"] == 2022) &
        (dataset_final["MES"].isin(["Enero", "Febrero", "Marzo", "Abril"]))
    )
].copy()

# %%
# Se revisa la estructura general del DataFrame:
# número de observaciones, columnas, tipos de datos y valores no nulos.
dataset_final.shape
# Out:
# (1208, 34)

# %%
# Se revisan específicamente los tipos de datos de las variables
# posteriores a las tres primeras columnas de identificación.
dataset_final
# Out:
#         MES   AÑO                                            ENTIDAD  \
# 96     Mayo  2022                                       BP GUAYAQUIL
# 97     Mayo  2022                                        BP PACIFICO
# 98     Mayo  2022                                       BP PICHINCHA
# 99     Mayo  2022                                      BP PRODUBANCO
# 100    Mayo  2022                                          BP AUSTRO
# ...     ...   ...                                                ...
# 1299  Julio  2026                                         BP CAPITAL
# 1300  Julio  2026                                         BP DELBANK
# 1301  Julio  2026                BP D-MIRO S.A./BANCO ATLÁNTIDA S.A.
# 1302  Julio  2026  BP BANCO  DESARROLLO DE LOS PUEBLOS  S.A., COD...
# 1303  Julio  2026                         BP VISIONFUND ECUADOR S.A.
#
#      ( PATRIMONIO + RESULTADOS ) / ACTIVOS INMOVILIZADOS NETOS (3) (6)  \
# 96                                             4.106345
# 97                                              2.76007
# 98                                           -12.882069
# 99                                             3.457887
# 100                                            1.295431
# ...                                                 ...
# 1299                                           0.743608
# 1300                                           7.435204
# 1301                                           0.788369
# 1302                                           2.990621
# 1303                                           21.25641
#
#      INDICE DE CAPITALIZACION NETO: FK / FI  \
# 96                                 0.081208
# 97                                 0.095491
# 98                                 0.087281
# 99                                  0.07046
# 100                                0.077153
# ...                                     ...
# 1299                               0.088779
# 1300                               0.288765
# 1301                               0.055191
# 1302                               0.103658
# 1303                               0.128662
#
#      ACTIVOS IMPRODUCTIVOS NETOS / TOTAL ACTIVOS  \
# 96                                      0.133465
# 97                                      0.217156
# 98                                      0.087276
# 99                                      0.119412
# 100                                     0.160334
# ...                                          ...
# 1299                                    0.203118
# 1300                                    0.157979
# 1301                                    0.128191
# 1302                                    0.105249
# 1303                                    0.037131
#
#      ACTIVOS PRODUCTIVOS / TOTAL ACTIVOS  \
# 96                              0.866535
# 97                              0.782844
# 98                              0.912724
# 99                              0.880588
# 100                             0.839666
# ...                                  ...
# 1299                            0.796882
# 1300                            0.842021
# 1301                            0.871809
# 1302                            0.894751
# 1303                            0.962869
#
#      ACTIVOS PRODUCTIVOS / PASIVOS CON COSTO  \
# 96                                  1.204264
# 97                                  1.112745
# 98                                  1.423879
# 99                                   1.46171
# 100                                 1.042581
# ...                                      ...
# 1299                                0.974991
# 1300                                1.769811
# 1301                                 0.96599
# 1302                                1.069191
# 1303                                1.177842
#
#      MOROSIDAD DE LA CARTERA DE CREDITOS CONSUMO  \
# 96                                      0.015497
# 97                                      0.032618
# 98                                       0.02102
# 99                                      0.029096
# 100                                     0.077468
# ...                                          ...
# 1299                                    0.035269
# 1300                                    0.105913
# 1301                                    0.000358
# 1302                                    0.079619
# 1303                                    0.008478
#
#      MOROSIDAD DE LA CARTERA DE CRÉDITOS INMOBILIARIO  ...  \
# 96                                           0.018206  ...
# 97                                           0.044019  ...
# 98                                           0.042779  ...
# 99                                            0.02892  ...
# 100                                          0.016729  ...
# ...                                               ...  ...
# 1299                                                0  ...
# 1300                                         0.000002  ...
# 1301                                                0  ...
# 1302                                         0.006083  ...
# 1303                                                0  ...
#
#      CARTERA QUE NO DEVENGA INTERESES / CARTERA BRUTA  \
# 96                                           0.007049
# 97                                           0.017987
# 98                                           0.017432
# 99                                           0.010628
# 100                                          0.025212
# ...                                               ...
# 1299                                         0.041185
# 1300                                         0.020171
# 1301                                         0.012358
# 1302                                         0.058904
# 1303                                         0.022598
#
#      CARTERA REFINANCIADA / CARTERA BRUTA  \
# 96                               0.017101
# 97                               0.095438
# 98                               0.021698
# 99                               0.006073
# 100                              0.070088
# ...                                   ...
# 1299                             0.014315
# 1300                             0.068912
# 1301                             0.028839
# 1302                             0.041134
# 1303                             0.007556
#
#      CARTERA REESTRUCTURADA / CARTERA BRUTA VAR_FONDOS DISPONIBLES  \
# 96                                 0.005272              -0.153575
# 97                                 0.041668              -0.161024
# 98                                 0.047222              -0.345962
# 99                                 0.024845              -0.045015
# 100                                0.027836              -0.159378
# ...                                     ...                    ...
# 1299                               0.002475              -0.017643
# 1300                               0.003849               0.096224
# 1301                               0.007510               1.398896
# 1302                               0.006622              -0.585971
# 1303                               0.000656               0.114965
#
#      VAR_INVERSIONES VAR_CARTERA DE CRÉDITOS VAR_TOTAL ACTIVO  \
# 96         -0.031059                0.219636         0.108500
# 97          0.152143               -0.006714        -0.002157
# 98          0.008894                0.341896         0.106841
# 99         -0.035218                0.241502         0.138065
# 100         0.069119                0.214098         0.114007
# ...              ...                     ...              ...
# 1299        0.545330                0.434054         0.322436
# 1300       -0.379255               -0.118974        -0.102445
# 1301        0.509052                0.781038         0.712938
# 1302        0.248656                0.036946        -0.051873
# 1303        0.669452                0.232972         0.232023
#
#      VAR_Depósitos a la vista VAR_Depósitos a plazo VAR_TOTAL PATRIMONIO
# 96                   0.144194              0.163349             0.080876
# 97                  -0.037496              0.076166             0.020035
# 98                   0.090957              0.176605             0.043768
# 99                   0.092976              0.119563             0.077973
# 100                  0.078231              0.048206             0.128133
# ...                       ...                   ...                  ...
# 1299                 0.046285              0.445646             0.040729
# 1300                -0.125425             -0.227068             0.051840
# 1301                 0.275121              1.096880            -0.056485
# 1302                -0.138384              0.086575             0.067031
# 1303                 0.450468              0.703935             0.078424
#
# [1208 rows x 34 columns]

# %%
dataset_final.iloc[:, 3:].dtypes
# Out:
# ( PATRIMONIO + RESULTADOS ) / ACTIVOS INMOVILIZADOS NETOS (3) (6)     object
# INDICE DE CAPITALIZACION NETO: FK / FI                                object
# ACTIVOS IMPRODUCTIVOS NETOS / TOTAL ACTIVOS                           object
# ACTIVOS PRODUCTIVOS / TOTAL ACTIVOS                                   object
# ACTIVOS PRODUCTIVOS / PASIVOS CON COSTO                               object
# MOROSIDAD DE LA CARTERA DE CREDITOS CONSUMO                           object
# MOROSIDAD DE LA CARTERA DE CRÉDITOS INMOBILIARIO                      object
# MOROSIDAD DE LA CARTERA DE CRÉDITOS MICROCRÉDITO                      object
# MOROSIDAD DE LA CARTERA TOTAL                                         object
# COBERTURA DE LA CARTERA REFINANCIADA                                  object
# COBERTURA DE LA CARTERA REESTRUCTURADA                                object
# COBERTURA DE LA CARTERA PROBLEMÁTICA                                  object
# GASTOS DE OPERACION ESTIMADOS / TOTAL ACTIVO PROMEDIO (3)             object
# GASTOS DE OPERACION  / MARGEN FINANCIERO                              object
# GASTOS DE PERSONAL ESTIMADOS / ACTIVO PROMEDIO (3)                    object
# RESULTADOS DEL EJERCICIO / PATRIMONIO PROMEDIO                        object
# RESULTADOS DEL EJERCICIO / ACTIVO PROMEDIO                            object
# CARTERA BRUTA / (DEPOSITOS A LA VISTA + DEPOSITOS A PLAZO)            object
# FONDOS DISPONIBLES / TOTAL DEPOSITOS A CORTO PLAZO                    object
# CARTERA IMPRODUCTIVA / CARTERA BRUTA                                 float64
# CARTERA VENCIDA / CARTERA BRUTA                                      float64
# CARTERA QUE NO DEVENGA INTERESES / CARTERA BRUTA                     float64
# CARTERA REFINANCIADA / CARTERA BRUTA                                 float64
# CARTERA REESTRUCTURADA / CARTERA BRUTA                               float64
# VAR_FONDOS DISPONIBLES                                               float64
# VAR_INVERSIONES                                                      float64
# VAR_CARTERA DE CRÉDITOS                                              float64
# VAR_TOTAL ACTIVO                                                     float64
# VAR_Depósitos a la vista                                             float64
# VAR_Depósitos a plazo                                                float64
# VAR_TOTAL PATRIMONIO                                                 float64
# dtype: object

# %%
# Se separan las variables de identificación de las variables
# utilizadas como indicadores financieros.
#
# MES, AÑO y ENTIDAD identifican cada observación, mientras que
# las demás columnas corresponden a variables cuantitativas.

columnas_numericas = [
    col for col in dataset_final.columns
    if col not in ["MES", "AÑO", "ENTIDAD"]
]

columnas_no_numericas = [ "MES", "AÑO", "ENTIDAD"]

# %%
# Se convierten las variables financieras a valores numéricos.
#
# errors="coerce" transforma en NaN aquellos valores que no puedan
# convertirse correctamente a número, evitando que un valor inválido
# detenga todo el procesamiento.
#
# Finalmente, se utiliza float64 para mantener un tipo numérico
# homogéneo y compatible con los análisis posteriores.

dataset_final[columnas_numericas] = (
    dataset_final[columnas_numericas]
    .apply(pd.to_numeric, errors="coerce")
    .astype("float64")
)

# %%
# Se convierten las variables de identificación a texto para
# mantener un formato homogéneo en la base

dataset_final[columnas_no_numericas] = (
    dataset_final[columnas_no_numericas]
    .astype(str)
)

# %%
dataset_final.describe()
# Out:
#        ( PATRIMONIO + RESULTADOS ) / ACTIVOS INMOVILIZADOS NETOS (3) (6)  \
# count                                        1208.000000
# mean                                           16.564382
# std                                           508.772993
# min                                         -1123.052066
# 25%                                             0.884036
# 50%                                             2.636429
# 75%                                             5.604946
# max                                         17606.001928
#
#        INDICE DE CAPITALIZACION NETO: FK / FI  \
# count                             1208.000000
# mean                                 0.113417
# std                                  0.096263
# min                                 -2.589472
# 25%                                  0.079909
# 50%                                  0.092059
# 75%                                  0.142611
# max                                  0.341963
#
#        ACTIVOS IMPRODUCTIVOS NETOS / TOTAL ACTIVOS  \
# count                                  1208.000000
# mean                                      0.129656
# std                                       0.067545
# min                                      -0.002645
# 25%                                       0.085705
# 50%                                       0.115675
# 75%                                       0.158279
# max                                       0.416821
#
#        ACTIVOS PRODUCTIVOS / TOTAL ACTIVOS  \
# count                          1208.000000
# mean                              0.870344
# std                               0.067545
# min                               0.583179
# 25%                               0.841721
# 50%                               0.884325
# 75%                               0.914295
# max                               1.002645
#
#        ACTIVOS PRODUCTIVOS / PASIVOS CON COSTO  \
# count                              1208.000000
# mean                                  1.452182
# std                                   1.548236
# min                                   0.212959
# 25%                                   1.059337
# 50%                                   1.140050
# 75%                                   1.306533
# max                                  23.509207
#
#        MOROSIDAD DE LA CARTERA DE CREDITOS CONSUMO  \
# count                                  1208.000000
# mean                                      0.049878
# std                                       0.039261
# min                                       0.000000
# 25%                                       0.028479
# 50%                                       0.046086
# 75%                                       0.062934
# max                                       0.430763
#
#        MOROSIDAD DE LA CARTERA DE CRÉDITOS INMOBILIARIO  \
# count                                       1208.000000
# mean                                           0.066555
# std                                            0.207324
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            0.014703
# 75%                                            0.028413
# max                                            1.000000
#
#        MOROSIDAD DE LA CARTERA DE CRÉDITOS MICROCRÉDITO  \
# count                                       1208.000000
# mean                                           0.089563
# std                                            0.125578
# min                                            0.000000
# 25%                                            0.024433
# 50%                                            0.052714
# 75%                                            0.112452
# max                                            1.000000
#
#        MOROSIDAD DE LA CARTERA TOTAL  COBERTURA DE LA CARTERA REFINANCIADA  \
# count                    1208.000000                           1208.000000
# mean                        0.047017                              1.040733
# std                         0.046990                              1.290756
# min                         0.000000                              0.000000
# 25%                         0.023536                              0.584152
# 50%                         0.034540                              0.814337
# 75%                         0.054207                              1.058919
# max                         0.313073                             14.657317
#
#        ...  CARTERA QUE NO DEVENGA INTERESES / CARTERA BRUTA  \
# count  ...                                       1207.000000
# mean   ...                                          0.031721
# std    ...                                          0.030505
# min    ...                                          0.000000
# 25%    ...                                          0.016404
# 50%    ...                                          0.024161
# 75%    ...                                          0.035671
# max    ...                                          0.205025
#
#        CARTERA REFINANCIADA / CARTERA BRUTA  \
# count                           1207.000000
# mean                               0.036880
# std                                0.035211
# min                                0.000000
# 25%                                0.009921
# 50%                                0.026232
# 75%                                0.054642
# max                                0.189812
#
#        CARTERA REESTRUCTURADA / CARTERA BRUTA  VAR_FONDOS DISPONIBLES  \
# count                             1207.000000             1208.000000
# mean                                 0.019650                0.114038
# std                                  0.020487                0.452901
# min                                  0.000000               -0.731714
# 25%                                  0.004368               -0.124675
# 50%                                  0.013293                0.041677
# 75%                                  0.027514                0.236876
# max                                  0.116167                7.810275
#
#        VAR_INVERSIONES  VAR_CARTERA DE CRÉDITOS  VAR_TOTAL ACTIVO  \
# count      1208.000000              1208.000000       1208.000000
# mean          0.229692                 0.099536          0.097517
# std           0.599447                 0.194632          0.133781
# min          -0.761311                -1.000000         -0.884704
# 25%          -0.086429                 0.034203          0.029916
# 50%           0.137785                 0.098010          0.091172
# 75%           0.368646                 0.155629          0.143349
# max           4.724520                 1.067010          0.849168
#
#        VAR_Depósitos a la vista  VAR_Depósitos a plazo  VAR_TOTAL PATRIMONIO
# count               1208.000000            1208.000000           1208.000000
# mean                   0.190345              25.440645              0.058678
# std                    0.655566             437.046134              0.135612
# min                   -0.684559              -1.000000             -0.772532
# 25%                   -0.030455               0.030487              0.013970
# 50%                    0.070587               0.122532              0.063610
# 75%                    0.224256               0.231238              0.103479
# max                    8.649531            9494.059333              1.048895
#
# [8 rows x 31 columns]

# %% [markdown]
# Se multiplican las variables numéricas por 100 para llevar las proporciones expresadas en formato decimal a una escala porcentual.

# %%
# Los indicadores financieros se expresan en proporciones en la
# fuente de cálculo. Se multiplican por 100 para expresarlos
# porcentualmente y facilitar su interpretación.

dataset_final[columnas_numericas] = (
    dataset_final[columnas_numericas] * 100
)

# %%
dataset_final.describe()
# Out:
#        ( PATRIMONIO + RESULTADOS ) / ACTIVOS INMOVILIZADOS NETOS (3) (6)  \
# count                                       1.208000e+03
# mean                                        1.656438e+03
# std                                         5.087730e+04
# min                                        -1.123052e+05
# 25%                                         8.840359e+01
# 50%                                         2.636429e+02
# 75%                                         5.604946e+02
# max                                         1.760600e+06
#
#        INDICE DE CAPITALIZACION NETO: FK / FI  \
# count                             1208.000000
# mean                                11.341694
# std                                  9.626256
# min                               -258.947223
# 25%                                  7.990934
# 50%                                  9.205931
# 75%                                 14.261135
# max                                 34.196266
#
#        ACTIVOS IMPRODUCTIVOS NETOS / TOTAL ACTIVOS  \
# count                                  1208.000000
# mean                                     12.965590
# std                                       6.754526
# min                                      -0.264501
# 25%                                       8.570496
# 50%                                      11.567498
# 75%                                      15.827885
# max                                      41.682135
#
#        ACTIVOS PRODUCTIVOS / TOTAL ACTIVOS  \
# count                          1208.000000
# mean                             87.034410
# std                               6.754526
# min                              58.317865
# 25%                              84.172115
# 50%                              88.432502
# 75%                              91.429504
# max                             100.264501
#
#        ACTIVOS PRODUCTIVOS / PASIVOS CON COSTO  \
# count                              1208.000000
# mean                                145.218249
# std                                 154.823626
# min                                  21.295925
# 25%                                 105.933679
# 50%                                 114.004995
# 75%                                 130.653288
# max                                2350.920665
#
#        MOROSIDAD DE LA CARTERA DE CREDITOS CONSUMO  \
# count                                  1208.000000
# mean                                      4.987763
# std                                       3.926121
# min                                       0.000000
# 25%                                       2.847946
# 50%                                       4.608605
# 75%                                       6.293386
# max                                      43.076268
#
#        MOROSIDAD DE LA CARTERA DE CRÉDITOS INMOBILIARIO  \
# count                                       1208.000000
# mean                                           6.655453
# std                                           20.732450
# min                                            0.000000
# 25%                                            0.000000
# 50%                                            1.470285
# 75%                                            2.841323
# max                                          100.000000
#
#        MOROSIDAD DE LA CARTERA DE CRÉDITOS MICROCRÉDITO  \
# count                                       1208.000000
# mean                                           8.956287
# std                                           12.557807
# min                                            0.000000
# 25%                                            2.443350
# 50%                                            5.271447
# 75%                                           11.245163
# max                                          100.000000
#
#        MOROSIDAD DE LA CARTERA TOTAL  COBERTURA DE LA CARTERA REFINANCIADA  \
# count                    1208.000000                           1208.000000
# mean                        4.701747                            104.073253
# std                         4.699044                            129.075563
# min                         0.000000                              0.000000
# 25%                         2.353552                             58.415206
# 50%                         3.453965                             81.433699
# 75%                         5.420679                            105.891938
# max                        31.307321                           1465.731674
#
#        ...  CARTERA QUE NO DEVENGA INTERESES / CARTERA BRUTA  \
# count  ...                                       1207.000000
# mean   ...                                          3.172085
# std    ...                                          3.050455
# min    ...                                          0.000000
# 25%    ...                                          1.640437
# 50%    ...                                          2.416134
# 75%    ...                                          3.567129
# max    ...                                         20.502539
#
#        CARTERA REFINANCIADA / CARTERA BRUTA  \
# count                           1207.000000
# mean                               3.688033
# std                                3.521125
# min                                0.000000
# 25%                                0.992060
# 50%                                2.623152
# 75%                                5.464191
# max                               18.981181
#
#        CARTERA REESTRUCTURADA / CARTERA BRUTA  VAR_FONDOS DISPONIBLES  \
# count                             1207.000000             1208.000000
# mean                                 1.964977               11.403789
# std                                  2.048710               45.290140
# min                                  0.000000              -73.171448
# 25%                                  0.436808              -12.467466
# 50%                                  1.329306                4.167747
# 75%                                  2.751399               23.687607
# max                                 11.616699              781.027486
#
#        VAR_INVERSIONES  VAR_CARTERA DE CRÉDITOS  VAR_TOTAL ACTIVO  \
# count      1208.000000              1208.000000       1208.000000
# mean         22.969206                 9.953627          9.751733
# std          59.944724                19.463239         13.378119
# min         -76.131089              -100.000000        -88.470411
# 25%          -8.642882                 3.420324          2.991587
# 50%          13.778457                 9.801012          9.117156
# 75%          36.864567                15.562938         14.334863
# max         472.451991               106.701001         84.916787
#
#        VAR_Depósitos a la vista  VAR_Depósitos a plazo  VAR_TOTAL PATRIMONIO
# count               1208.000000            1208.000000           1208.000000
# mean                  19.034497            2544.064522              5.867807
# std                   65.556642           43704.613438             13.561230
# min                  -68.455858            -100.000000            -77.253164
# 25%                   -3.045542               3.048667              1.397009
# 50%                    7.058723              12.253199              6.361039
# 75%                   22.425626              23.123778             10.347918
# max                  864.953131          949405.933333            104.889489
#
# [8 rows x 31 columns]

# %%
dataset_final.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1208 entries, 96 to 1303
# Data columns (total 34 columns):
#  #   Column                                                             Non-Null Count  Dtype
# ---  ------                                                             --------------  -----
#  0   MES                                                                1208 non-null   str
#  1   AÑO                                                                1208 non-null   str
#  2   ENTIDAD                                                            1208 non-null   str
#  3   ( PATRIMONIO + RESULTADOS ) / ACTIVOS INMOVILIZADOS NETOS (3) (6)  1208 non-null   float64
#  4   INDICE DE CAPITALIZACION NETO: FK / FI                             1208 non-null   float64
#  5   ACTIVOS IMPRODUCTIVOS NETOS / TOTAL ACTIVOS                        1208 non-null   float64
#  6   ACTIVOS PRODUCTIVOS / TOTAL ACTIVOS                                1208 non-null   float64
#  7   ACTIVOS PRODUCTIVOS / PASIVOS CON COSTO                            1208 non-null   float64
#  8   MOROSIDAD DE LA CARTERA DE CREDITOS CONSUMO                        1208 non-null   float64
#  9   MOROSIDAD DE LA CARTERA DE CRÉDITOS INMOBILIARIO                   1208 non-null   float64
#  10  MOROSIDAD DE LA CARTERA DE CRÉDITOS MICROCRÉDITO                   1208 non-null   float64
#  11  MOROSIDAD DE LA CARTERA TOTAL                                      1208 non-null   float64
#  12  COBERTURA DE LA CARTERA REFINANCIADA                               1208 non-null   float64
#  13  COBERTURA DE LA CARTERA REESTRUCTURADA                             1208 non-null   float64
#  14  COBERTURA DE LA CARTERA PROBLEMÁTICA                               1208 non-null   float64
#  15  GASTOS DE OPERACION ESTIMADOS / TOTAL ACTIVO PROMEDIO (3)          1208 non-null   float64
#  16  GASTOS DE OPERACION  / MARGEN FINANCIERO                           1208 non-null   float64
#  17  GASTOS DE PERSONAL ESTIMADOS / ACTIVO PROMEDIO (3)                 1208 non-null   float64
#  18  RESULTADOS DEL EJERCICIO / PATRIMONIO PROMEDIO                     1208 non-null   float64
#  19  RESULTADOS DEL EJERCICIO / ACTIVO PROMEDIO                         1208 non-null   float64
#  20  CARTERA BRUTA / (DEPOSITOS A LA VISTA + DEPOSITOS A PLAZO)         1208 non-null   float64
#  21  FONDOS DISPONIBLES / TOTAL DEPOSITOS A CORTO PLAZO                 1208 non-null   float64
#  22  CARTERA IMPRODUCTIVA / CARTERA BRUTA                               1207 non-null   float64
#  23  CARTERA VENCIDA / CARTERA BRUTA                                    1207 non-null   float64
#  24  CARTERA QUE NO DEVENGA INTERESES / CARTERA BRUTA                   1207 non-null   float64
#  25  CARTERA REFINANCIADA / CARTERA BRUTA                               1207 non-null   float64
#  26  CARTERA REESTRUCTURADA / CARTERA BRUTA                             1207 non-null   float64
#  27  VAR_FONDOS DISPONIBLES                                             1208 non-null   float64
#  28  VAR_INVERSIONES                                                    1208 non-null   float64
#  29  VAR_CARTERA DE CRÉDITOS                                            1208 non-null   float64
#  30  VAR_TOTAL ACTIVO                                                   1208 non-null   float64
#  31  VAR_Depósitos a la vista                                           1208 non-null   float64
#  32  VAR_Depósitos a plazo                                              1208 non-null   float64
#  33  VAR_TOTAL PATRIMONIO                                               1208 non-null   float64
# dtypes: float64(31), str(3)
# memory usage: 321.0 KB

# %%
# Se construye una tabla de diagnóstico de valores nulos.
#
# Cantidad_nulos indica cuántas observaciones faltantes existen
# en cada variable.
#
# Porcentaje_nulos expresa los valores faltantes como porcentaje
# del total de observaciones.

nulos = pd.DataFrame({
    "Variable": dataset_final.columns,
    "Cantidad_nulos": dataset_final.isna().sum().values,
    "Porcentaje_nulos": (
        dataset_final.isna().mean().values * 100
    )
})

nulos
# Out:
#                                              Variable  Cantidad_nulos  \
# 0                                                 MES               0
# 1                                                 AÑO               0
# 2                                             ENTIDAD               0
# 3   ( PATRIMONIO + RESULTADOS ) / ACTIVOS INMOVILI...               0
# 4              INDICE DE CAPITALIZACION NETO: FK / FI               0
# 5         ACTIVOS IMPRODUCTIVOS NETOS / TOTAL ACTIVOS               0
# 6                 ACTIVOS PRODUCTIVOS / TOTAL ACTIVOS               0
# 7             ACTIVOS PRODUCTIVOS / PASIVOS CON COSTO               0
# 8         MOROSIDAD DE LA CARTERA DE CREDITOS CONSUMO               0
# 9    MOROSIDAD DE LA CARTERA DE CRÉDITOS INMOBILIARIO               0
# 10   MOROSIDAD DE LA CARTERA DE CRÉDITOS MICROCRÉDITO               0
# 11                      MOROSIDAD DE LA CARTERA TOTAL               0
# 12               COBERTURA DE LA CARTERA REFINANCIADA               0
# 13             COBERTURA DE LA CARTERA REESTRUCTURADA               0
# 14               COBERTURA DE LA CARTERA PROBLEMÁTICA               0
# 15  GASTOS DE OPERACION ESTIMADOS / TOTAL ACTIVO P...               0
# 16           GASTOS DE OPERACION  / MARGEN FINANCIERO               0
# 17  GASTOS DE PERSONAL ESTIMADOS / ACTIVO PROMEDIO...               0
# 18     RESULTADOS DEL EJERCICIO / PATRIMONIO PROMEDIO               0
# 19         RESULTADOS DEL EJERCICIO / ACTIVO PROMEDIO               0
# 20  CARTERA BRUTA / (DEPOSITOS A LA VISTA + DEPOSI...               0
# 21  FONDOS DISPONIBLES / TOTAL DEPOSITOS A CORTO P...               0
# 22               CARTERA IMPRODUCTIVA / CARTERA BRUTA               1
# 23                    CARTERA VENCIDA / CARTERA BRUTA               1
# 24   CARTERA QUE NO DEVENGA INTERESES / CARTERA BRUTA               1
# 25               CARTERA REFINANCIADA / CARTERA BRUTA               1
# 26             CARTERA REESTRUCTURADA / CARTERA BRUTA               1
# 27                             VAR_FONDOS DISPONIBLES               0
# 28                                    VAR_INVERSIONES               0
# 29                            VAR_CARTERA DE CRÉDITOS               0
# 30                                   VAR_TOTAL ACTIVO               0
# 31                           VAR_Depósitos a la vista               0
# 32                              VAR_Depósitos a plazo               0
# 33                               VAR_TOTAL PATRIMONIO               0
#
#     Porcentaje_nulos
# 0           0.000000
# 1           0.000000
# 2           0.000000
# 3           0.000000
# 4           0.000000
# 5           0.000000
# 6           0.000000
# 7           0.000000
# 8           0.000000
# 9           0.000000
# 10          0.000000
# 11          0.000000
# 12          0.000000
# 13          0.000000
# 14          0.000000
# 15          0.000000
# 16          0.000000
# 17          0.000000
# 18          0.000000
# 19          0.000000
# 20          0.000000
# 21          0.000000
# 22          0.082781
# 23          0.082781
# 24          0.082781
# 25          0.082781
# 26          0.082781
# 27          0.000000
# 28          0.000000
# 29          0.000000
# 30          0.000000
# 31          0.000000
# 32          0.000000
# 33          0.000000

# %%
# Se ordenan las variables de mayor a menor cantidad de valores
# nulos para identificar rápidamente aquellas que requieren
# revisión.


nulos = nulos.sort_values(
    "Cantidad_nulos",
    ascending=False
).reset_index(drop=True)

nulos
# Out:
#                                              Variable  Cantidad_nulos  \
# 0                     CARTERA VENCIDA / CARTERA BRUTA               1
# 1                CARTERA IMPRODUCTIVA / CARTERA BRUTA               1
# 2                CARTERA REFINANCIADA / CARTERA BRUTA               1
# 3              CARTERA REESTRUCTURADA / CARTERA BRUTA               1
# 4    CARTERA QUE NO DEVENGA INTERESES / CARTERA BRUTA               1
# 5                                                 MES               0
# 6                                                 AÑO               0
# 7                                             ENTIDAD               0
# 8              INDICE DE CAPITALIZACION NETO: FK / FI               0
# 9   ( PATRIMONIO + RESULTADOS ) / ACTIVOS INMOVILI...               0
# 10   MOROSIDAD DE LA CARTERA DE CRÉDITOS MICROCRÉDITO               0
# 11                      MOROSIDAD DE LA CARTERA TOTAL               0
# 12               COBERTURA DE LA CARTERA REFINANCIADA               0
# 13        ACTIVOS IMPRODUCTIVOS NETOS / TOTAL ACTIVOS               0
# 14                ACTIVOS PRODUCTIVOS / TOTAL ACTIVOS               0
# 15            ACTIVOS PRODUCTIVOS / PASIVOS CON COSTO               0
# 16        MOROSIDAD DE LA CARTERA DE CREDITOS CONSUMO               0
# 17   MOROSIDAD DE LA CARTERA DE CRÉDITOS INMOBILIARIO               0
# 18  GASTOS DE PERSONAL ESTIMADOS / ACTIVO PROMEDIO...               0
# 19           GASTOS DE OPERACION  / MARGEN FINANCIERO               0
# 20  GASTOS DE OPERACION ESTIMADOS / TOTAL ACTIVO P...               0
# 21               COBERTURA DE LA CARTERA PROBLEMÁTICA               0
# 22             COBERTURA DE LA CARTERA REESTRUCTURADA               0
# 23  FONDOS DISPONIBLES / TOTAL DEPOSITOS A CORTO P...               0
# 24         RESULTADOS DEL EJERCICIO / ACTIVO PROMEDIO               0
# 25  CARTERA BRUTA / (DEPOSITOS A LA VISTA + DEPOSI...               0
# 26     RESULTADOS DEL EJERCICIO / PATRIMONIO PROMEDIO               0
# 27                             VAR_FONDOS DISPONIBLES               0
# 28                                    VAR_INVERSIONES               0
# 29                            VAR_CARTERA DE CRÉDITOS               0
# 30                                   VAR_TOTAL ACTIVO               0
# 31                           VAR_Depósitos a la vista               0
# 32                              VAR_Depósitos a plazo               0
# 33                               VAR_TOTAL PATRIMONIO               0
#
#     Porcentaje_nulos
# 0           0.082781
# 1           0.082781
# 2           0.082781
# 3           0.082781
# 4           0.082781
# 5           0.000000
# 6           0.000000
# 7           0.000000
# 8           0.000000
# 9           0.000000
# 10          0.000000
# 11          0.000000
# 12          0.000000
# 13          0.000000
# 14          0.000000
# 15          0.000000
# 16          0.000000
# 17          0.000000
# 18          0.000000
# 19          0.000000
# 20          0.000000
# 21          0.000000
# 22          0.000000
# 23          0.000000
# 24          0.000000
# 25          0.000000
# 26          0.000000
# 27          0.000000
# 28          0.000000
# 29          0.000000
# 30          0.000000
# 31          0.000000
# 32          0.000000
# 33          0.000000

# %% [markdown]
# Se identifican los indicadores de cartera que presentaron
# observaciones nulas durante la validación.
#
# Estas variables se construyen a partir de divisiones entre
# componentes de cartera y CARTERA BRUTA, por lo que un NaN
# puede aparecer cuando el denominador no permite realizar
# el cálculo.

# %%
columnas_con_un_nulo=["CARTERA QUE NO DEVENGA INTERESES / CARTERA BRUTA"
,"CARTERA REFINANCIADA / CARTERA BRUTA"
,"CARTERA VENCIDA / CARTERA BRUTA"
,"CARTERA IMPRODUCTIVA / CARTERA BRUTA"
,"CARTERA REESTRUCTURADA / CARTERA BRUTA"]

# %% [markdown]
# Se encontró un registro con valor `NAN` en todos las variables construidas de cartera. Esta  observación específica identificada corresponde a Marzo 2025 BP FINCA S.A./BANCO AMIBANK S.A. y se elimina este registro del dataset porque después de varias intervenciones por parte de la Superintendencia de Bancos, la entidad es cerrada e ingresa en un proceso de liquidación  el 11 de Marzo de 2025  debido a pérdidas continuas y deficiencias en su gestión.

# %%
dataset_final.loc[
    dataset_final[columnas_con_un_nulo].isna().any(axis=1),
    ["AÑO", "MES", "ENTIDAD"] + columnas_con_un_nulo
]
# Out:
#       AÑO    MES                           ENTIDAD  \
# 931  2025  Marzo  BP FINCA S.A./BANCO AMIBANK S.A.
#
#      CARTERA QUE NO DEVENGA INTERESES / CARTERA BRUTA  \
# 931                                               NaN
#
#      CARTERA REFINANCIADA / CARTERA BRUTA  CARTERA VENCIDA / CARTERA BRUTA  \
# 931                                   NaN                              NaN
#
#      CARTERA IMPRODUCTIVA / CARTERA BRUTA  \
# 931                                   NaN
#
#      CARTERA REESTRUCTURADA / CARTERA BRUTA
# 931                                     NaN

# %%
base_sin_eliminar=dataset_final.copy()

# %%
dataset_final.shape
# Out:
# (1208, 34)

# %%
dataset_final = dataset_final[
    ~(
        (dataset_final["AÑO"] == "2025") &
        (dataset_final["MES"].str.strip() == "Marzo") &
        (dataset_final["ENTIDAD"] == "BP FINCA S.A./BANCO AMIBANK S.A.")
    )
].copy()

# %%
dataset_final.shape
# Out:
# (1207, 34)

# %% [markdown]
# ### Detección de duplicados

# %%
def detectar_duplicados(df):
    """
    Cuenta las observaciones duplicadas utilizando AÑO, MES y ENTIDAD
    como llave lógica de identificación.
    Parámetros-> df: dataframe a validar.
    Salida-> número que indica la cantidad de observaciones según la 
    llave definida"""
    return df.duplicated(
        subset=["AÑO", "MES", "ENTIDAD"]
    ).sum()

# %%
# Se verifica si existen registros repetidos para una misma
# entidad y período.
detectar_duplicados(dataset_final)
# Out:
# np.int64(0)

# %% [markdown]
# ### Detección de infinitos en las variables numéricas

# %%
def detectar_infinitos(df):
    """Cuenta los valores infinitos presentes en las variables numéricas.
    Parámetros->df : dataframe que se desea validar.
    Salida-> serie que indica el número de valores infinitos por variable numérica."""

    # Se seleccionan únicamente las columnas numéricas, ya que
    # los valores infinitos pueden afectar los análisis posteriores.
    columnas_numericas = df.select_dtypes(
        include="number"
    ).columns

    # Se cuentan los valores positivos y negativos infinitos
    # presentes en cada variable.
    return np.isinf(
        df[columnas_numericas]
    ).sum()

# %%
detectar_infinitos(dataset_final)
# Out:
# ( PATRIMONIO + RESULTADOS ) / ACTIVOS INMOVILIZADOS NETOS (3) (6)    0
# INDICE DE CAPITALIZACION NETO: FK / FI                               0
# ACTIVOS IMPRODUCTIVOS NETOS / TOTAL ACTIVOS                          0
# ACTIVOS PRODUCTIVOS / TOTAL ACTIVOS                                  0
# ACTIVOS PRODUCTIVOS / PASIVOS CON COSTO                              0
# MOROSIDAD DE LA CARTERA DE CREDITOS CONSUMO                          0
# MOROSIDAD DE LA CARTERA DE CRÉDITOS INMOBILIARIO                     0
# MOROSIDAD DE LA CARTERA DE CRÉDITOS MICROCRÉDITO                     0
# MOROSIDAD DE LA CARTERA TOTAL                                        0
# COBERTURA DE LA CARTERA REFINANCIADA                                 0
# COBERTURA DE LA CARTERA REESTRUCTURADA                               0
# COBERTURA DE LA CARTERA PROBLEMÁTICA                                 0
# GASTOS DE OPERACION ESTIMADOS / TOTAL ACTIVO PROMEDIO (3)            0
# GASTOS DE OPERACION  / MARGEN FINANCIERO                             0
# GASTOS DE PERSONAL ESTIMADOS / ACTIVO PROMEDIO (3)                   0
# RESULTADOS DEL EJERCICIO / PATRIMONIO PROMEDIO                       0
# RESULTADOS DEL EJERCICIO / ACTIVO PROMEDIO                           0
# CARTERA BRUTA / (DEPOSITOS A LA VISTA + DEPOSITOS A PLAZO)           0
# FONDOS DISPONIBLES / TOTAL DEPOSITOS A CORTO PLAZO                   0
# CARTERA IMPRODUCTIVA / CARTERA BRUTA                                 0
# CARTERA VENCIDA / CARTERA BRUTA                                      0
# CARTERA QUE NO DEVENGA INTERESES / CARTERA BRUTA                     0
# CARTERA REFINANCIADA / CARTERA BRUTA                                 0
# CARTERA REESTRUCTURADA / CARTERA BRUTA                               0
# VAR_FONDOS DISPONIBLES                                               0
# VAR_INVERSIONES                                                      0
# VAR_CARTERA DE CRÉDITOS                                              0
# VAR_TOTAL ACTIVO                                                     0
# VAR_Depósitos a la vista                                             0
# VAR_Depósitos a plazo                                                0
# VAR_TOTAL PATRIMONIO                                                 0
# dtype: int64

# %% [markdown]
# ### Entidades consideradas

# %%
dataset_final["ENTIDAD"].unique()
# Out:
# <StringArray>
# [                                           'BP GUAYAQUIL',
#                                              'BP PACIFICO',
#                                             'BP PICHINCHA',
#                                            'BP PRODUBANCO',
#                                                'BP AUSTRO',
#                                           'BP BOLIVARIANO',
#                                              'BP CITIBANK',
#                                                'BP DINERS',
#                                     'BP GENERAL RUMIÑAHUI',
#                                         'BP INTERNACIONAL',
#                                                  'BP LOJA',
#                                               'BP MACHALA',
#                                             'BP SOLIDARIO',
#                                             'BP PROCREDIT',
#                                              'BP AMAZONAS',
#                             'BP BANCO COMERCIAL DE MANABI',
#                                               'BP LITORAL',
#                                          'BP COOPNACIONAL',
#                                               'BP CAPITAL',
#                         'BP FINCA S.A./BANCO AMIBANK S.A.',
#                                               'BP DELBANK',
#                      'BP D-MIRO S.A./BANCO ATLÁNTIDA S.A.',
#  'BP BANCO  DESARROLLO DE LOS PUEBLOS  S.A., CODESARROLLO',
#                               'BP VISIONFUND ECUADOR S.A.']
# Length: 24, dtype: str

# %% [markdown]
# ## Generación de base limpia y registro del preprocesamiento

# %%
# Se identifica la observación que será excluida de la base
# debido a los valores nulos detectados en los indicadores de cartera.
condicion_eliminacion = (
    (base_sin_eliminar["AÑO"] == "2025") &
    (base_sin_eliminar["MES"].str.strip() == "Marzo") &
    (base_sin_eliminar["ENTIDAD"] == "BP FINCA S.A./BANCO AMIBANK S.A.")
)

# Se obtiene la información de la fila antes de eliminarla,
# para conservar evidencia de la observación excluida.
fila_eliminada = base_sin_eliminar.loc[
    condicion_eliminacion
].copy()


variables_con_nulos = [
    columna
    for columna in columnas_con_un_nulo
    if fila_eliminada[columna].isna().any()
]



# --------------------------------------------------------
# Creación del log de preprocesamiento
# --------------------------------------------------------

log_preprocesamiento = {
    "proceso": "Preprocesamiento de datos",
    "fecha_ejecucion": datetime.now().isoformat(),
    "eliminaciones": [
        {
            "motivo": (
                "Se eliminó una observación debido a valores nulos "
                "detectados en indicadores de cartera."
                "debido a que la entidad entró en proceso de cierre y liquidación"
                "el 11 de Marzo de 2025"
            ),
            "anio": "2025",
            "mes": "Marzo",
            "entidad": "BP FINCA S.A./BANCO AMIBANK S.A.",
            "variables_con_nulos": variables_con_nulos,
            "filas_eliminadas": len(fila_eliminada),
            "tamaño del dataset":dataset_final.shape

        }
    ]
}

# --------------------------------------------------------
# Guardar el log en la carpeta results
# --------------------------------------------------------

ruta_results = RAIZ_PROYECTO / "results"

# Se crea la carpeta results si no existe.
ruta_results.mkdir(
    parents=True,
    exist_ok=True
)

ruta_log = (
    RAIZ_PROYECTO
    / "results"
    / "preprocessing_log1.json"
)

# Se guarda el registro en formato JSON.
with open(
    ruta_log,
    "w",
    encoding="utf-8"
) as archivo:

    json.dump(
        log_preprocesamiento,
        archivo,
        indent=4,
        ensure_ascii=False
    )

print(f"Log guardado en: {ruta_log}")
# Out:
# Log guardado en: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\results\preprocessing_log1.json

# %% [markdown]
# Se guarda en un log el detalle de los resultados y en data_processed la base preprocesada.

# %%
## Se almacena una copia del dataset finalizado
base_final = dataset_final.copy()

# %%
# Se construye la ruta de salida a partir de la raíz del proyecto.
ruta_salida = RAIZ_PROYECTO / "data_processed" / "base_preprocesada1.xlsx"

# Se crea la carpeta de salida si aún no existe.
ruta_salida.parent.mkdir(
    parents=True,
    exist_ok=True
)

# Se guarda la base preprocesada.
base_final.to_excel(
    ruta_salida,
    index=False
)

print(f"Base preprocesada guardada en: {ruta_salida}")
# Out:
# Base preprocesada guardada en: C:\Users\ASUS\Desktop\proyecto_usfq\Proyecto_usfq\data_processed\base_preprocesada1.xlsx

# %% [markdown]
# ### Conclusiones:
#
# 1. Se logró integrar información de diferentes fuentes y años.
# El flujo integra los indicadores, información de cartera y variaciones del balance para el período 2022–2026. Esto deja una base estructurada por AÑO, MES y ENTIDAD, que posteriormente permite comparar el comportamiento de cada banco a través del tiempo.
# 2. La información quedó estandarizada en variables numéricas, y se multiplicó por 100.
# 3. En el preprocessing conviertes las variables financieras a float64 y las variables categóricas (MES, AÑO, ENTIDAD) a texto. Esto es importante porque las fuentes originales son archivos Excel y pueden contener valores almacenados como texto. Además, en el feature engineering también conviertes explícitamente las variables financieras a numéricas usando errors="coerce".
# Se identificaron y trataron valores nulos derivados de los indicadores de cartera.
# Las variables de cartera se construyen dividiendo cada componente para CARTERA BRUTA. Cuando la cartera bruta es 0, el código reemplaza ese denominador por NaN, evitando realizar una división entre cero.
# Por tanto, los nulos encontrados en esas variables no necesariamente representan datos faltantes originales; pueden ser consecuencia de que no existe un denominador válido para calcular el indicador.
# 4. Se detectó un registro que debía excluirse del análisis.
# En el notebook identificas específicamente el registro correspondiente a marzo de 2025 de BP FINCA S.A./BANCO AMIBANK S.A. y posteriormente lo eliminas, esto debido a que el 11 de Marzo de 2025 la entidad entró en proceso de liquidación, razón de la inexistencia de datos de cartera.
# 5. No existen duplicados utilizando la llave lógica del dataset: AÑO, MES y ENTIDAD como identificadores. Esto es adecuado porque, conceptualmente, debería existir una observación por banco para cada período mensual.
# 6. Se verificó la presencia de valores infinitos.
# Incluyes explícitamente una revisión de inf y -inf en las variables numéricas. Esto es especialmente importante porque varias variables son ratios y podrían generar infinitos si un denominador fuera cero. No existen valores infinitos.
# 7. Se analizarán un total de 24 entidades financieras privadas desde Mayo 2021 a Julio 2026, período en el que el ente de control realizó un proceso de homologación de la información financiera para que los datos sean comparables en el tiempo
